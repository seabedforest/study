# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Earthquakes.csv',usecols=['Latitude','Longitude','Magnitude'])
data=data[data.Magnitude>5]
data.plot.scatter(x='Latitude',y='Longitude')
